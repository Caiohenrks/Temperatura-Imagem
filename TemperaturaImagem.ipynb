# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plot

PATH = "/content/drive/MyDrive/Colab Notebooks/imagens"

imgBGR = cv.imread (PATH + "/satelite.jpg", cv.IMREAD_COLOR)
imgGray = cv.imread (PATH + "/satelite.jpg", cv.IMREAD_GRAYSCALE)


imgRGB = cv.cvtColor(imgBGR, cv.COLOR_BGR2RGB)




##plot.imshow(imgRGB)
##plot.imshow(imgLena)

imgR, imgG, imgB = cv.split(imgRGB)

fig, (plot1, plot2) = plot.subplots(1, 2, figsize=(15,15))
plot2.imshow(imgR, cmap= "jet")
plot1.imshow(imgBGR)
